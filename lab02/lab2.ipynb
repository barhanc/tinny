# %%
import numpy as np
import matplotlib.pyplot as plt
# import mkl

from numpy.typing import NDArray
from matplotlib.axes import Axes
from matplotlib.figure import Figure

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %%
# arrange 2D matrices as tiles (takes 4D `examples` tensor with dims: rows x cols x tile_height x tile_width)
def tiles(examples: NDArray) -> NDArray:
    rows, cols, h, w = examples.shape
    space = 2

    img_matrix = np.ones(shape=(rows * h + (rows - 1) * space, cols * w + (cols - 1) * space))

    for r in range(rows):
        for c in range(cols):
            x0 = r * w + r * space
            y0 = c * h + c * space
            img_matrix[x0 : x0 + w, y0 : y0 + w] = examples[r, c, :, :]

    return img_matrix

# %% [markdown]
# ## MNIST Dataset

# %%
from mnists import MNIST

mnist = MNIST()

digits = mnist.train_images()[: 12 * 24].reshape(12, 24, 28, 28)
img = tiles(digits / 255.0)

plt.matshow(img, cmap="gray", interpolation="none")
plt.axis("off")
plt.show()

# %%
X = mnist.train_images().astype(np.float32) / 255.0
y = mnist.train_labels()
X.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# Reshape `X` so that the last two dimensions are collapsed into single dimension.

# %%
X = X.reshape(X.shape[0], -1)

# %%
X.shape
# Out:
# (60000, 784)

# %% [markdown]
# ## Visualizing the distribution of MNIST digits

# %% [markdown]
# Add a scatter plot to `plot`, which:
# * displys the first two dimensions of `X`,
# * includes only these elements from `X` for which `y == i` (i.e. elements from the i-th class),
# * includes label (i.e. `i`) in the legend.

# %%
def plot_2d_mnist_scatter(X: NDArray, y: NDArray):
    fig, plot = plt.subplots()
    fig.set_size_inches(16, 16)
    plt.prism()

    for i in range(10):
        mask = y == i
        plot.scatter(X[mask, 0], X[mask, 1], label=f"{i}")

    plot.set_xticks(())
    plot.set_yticks(())

    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# ### Principal Component Analysis (PCA)

# %%
SAMPLES_LIMIT = 2000
X_small = X[:SAMPLES_LIMIT]
y_small = y[:SAMPLES_LIMIT]

# %% [markdown]
# Use PCA function to embed `X_small` in two dimensions. Store the result in `X_pca_embedded`.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2, random_state=0)
X_pca_embedded = pca.fit_transform(X_small)

# %%
X_pca_embedded.shape
# Out:
# (2000, 2)

# %%
plot_2d_mnist_scatter(X_pca_embedded, y_small)

# %% [markdown]
# ### T-distributed Stochastic Neighbour Embedding (T-SNE)

# %% [markdown]
# Make sure to have a look on this increadible [article on T-SNE](https://distill.pub/2016/misread-tsne/).
#
# Use `T-SNE` function to embed `X_small` in two dimensions. Store the result in `X_tsne_embedded`. <BR>
# Use:
#  * `n_iter=500` argument to limit the number of T-SNE iterations,
#  * `verbose=2` argument to see a verbose output during embedding.

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=0, max_iter=500, verbose=2)
X_tsne_embedded = tsne.fit_transform(X_small)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.001s...
# [t-SNE] Computed neighbors for 2000 samples in 0.090s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 2.528207
# [t-SNE] Computed conditional probabilities in 0.028s
# [t-SNE] Iteration 50: error = 77.8449936, gradient norm = 0.0138680 (50 iterations in 0.119s)
# [t-SNE] Iteration 100: error = 75.6764908, gradient norm = 0.0004129 (50 iterations in 0.086s)
# [t-SNE] Iteration 150: error = 75.6504517, gradient norm = 0.0006917 (50 iterations in 0.086s)
# [t-SNE] Iteration 200: error = 75.5896683, gradient norm = 0.0006408 (50 iterations in 0.096s)
# [t-SNE] Iteration 250: error = 75.5473785, gradient norm = 0.0003428 (50 iterations in 0.091s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.547379
# [t-SNE] Iteration 300: error = 1.7908239, gradient norm = 0.0210654 (50 iterations in 0.091s)
# [t-SNE] Iteration 350: error = 1.4700418, gradient norm = 0.0164654 (50 iterations in 0.080s)
# [t-SNE] Iteration 400: error = 1.3446065, gradient norm = 0.0138171 (50 iterations in 0.082s)
# [t-SNE] Iteration 450: error = 1.2794821, gradient norm = 0.0120562 (50 iterations in 0.090s)
# [t-SNE] Iteration 500: error = 1.2406952, gradient norm = 0.0105621 (50 iterations in 0.084s)
# [t-SNE] KL divergence after 500 iterations: 1.240695

# %%
X_tsne_embedded.shape
# Out:
# (2000, 2)

# %%
plot_2d_mnist_scatter(X_tsne_embedded, y_small)

# %% [markdown]
# ### 3D interactive plots with plotly

# %%
import plotly.io as pio
import plotly.graph_objs as go

from plotly.offline import init_notebook_mode, iplot

init_notebook_mode(connected=True)
# pio.renderers.default = "iframe"


def plot_3d_mnist_plotly_scatter(X: NDArray, y: NDArray):
    def make_trace(i):
        digit_indices = y == i
        return go.Scatter3d(
            x=X[digit_indices, 0],
            y=X[digit_indices, 1],
            z=X[digit_indices, 2],
            mode="markers",
            name=str(i),
            marker=dict(
                color=i, colorscale="Jet", size=4, symbol="circle", line=dict(color="rgb(204, 204, 204)", width=1)
            ),
        )

    traces = [make_trace(i) for i in range(10)]

    layout = go.Layout(margin=dict(l=0, r=0, b=0, t=0))
    fig = go.Figure(data=traces, layout=layout)
    iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %% [markdown]
# Use PCA function to embed `X_small` in **three** dimensions. Store the result in `X_3d_pca_embedded`.

# %%
pca_3d = PCA(n_components=3, random_state=0)
X_3d_pca_embedded = pca_3d.fit_transform(X_small)

# %%
X_3d_pca_embedded.shape
# Out:
# (2000, 3)

# %%
plot_3d_mnist_plotly_scatter(X_3d_pca_embedded, y_small)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="13b8861d-c3d1-4897-86c6-4e40bed0df99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("13b8861d-c3d1-4897-86c6-4e40bed0df99")) {                    Plotly.newPlot(                        "13b8861d-c3d1-4897-86c6-4e40bed0df99",                        [{"marker":{"color":0,"colorscale":[[0.0,"rgb(0,0,131)"],[0.2,"rgb(0,60,170)"],[0.4,"rgb(5,255,255)"],[0.6,"rgb(255,255,0)"],[0.8,"rgb(250,0,0)"],[1.0,"rgb(128,0,0)"]],"line":{"color":"rgb(204, 204, 204)","width":1},"size":4,"symbol":"circle"},"mode":"markers","name":"0","x":{"dtype":"f4","bdata":"kDuIQFQjikC74EBAwHOHQEdTzkCZ9ZZAdjSeQHsREz68M6JAjkxtQFfCmkDSM3dAZ4GoQOC8gz\u002f2AaRAGEQ\u002fQEijukAOFaZAWfIxQAVKjkD0HJpA1JJvQL3tiEBVVDo\u002fxPEGQBWSXkA0ptE+DDVYQBF0Jz5hnjhAJwsvv9FBvEB26OxAK3eHQCfy3UBLmZBAewpyQCyDjkBwKNdAg5X3QLmKwkCo5Z5AORuIQAsHikC\u002fpHlAbT2+QOk+t0AKiF5AWVCBQJ2p\u002fT\u002fPGK9Al1BjQPPcpUDFnb8\u002fI26RQJs0okBdNB1A3IZhQGGOWUB6iXFAy\u002flWQPAbp0Dp8KFAzfUmQD0vJkDiU\u002f0\u002f4Gw8QCe8t0BN47xAx+WQQKm8nkAqvSlAPg2ZQGvxwUCApJRAodMhQOUXtkChQahAvzh0QPBWNUCjmpxAGrOcQEJjuUA\u002fDqNAwE9SQOUVZ0AeighAdJXsP7XLpEDYmJs+llWpQMYMPEAQk\u002fw\u002fyGwUQCCpNkBh6Is\u002ftporQJZcLECtSLc\u002fc4aAQI32zD\u002fY8Jc\u002f6zihQMrqrj4PJcA\u002f7w9tQKTEoECrTFlA8IxVQB+CdT9PEoRAPhLiP1buND+cVo9AkQxfvTdV2UCom6JALEXVQPHXfkD9FoRA3XEhQBp0TEDdqYpAyI2fQPvrn0D9yAJBxpGdQKBRAEH9VtlAUF91QJ+ga0B8xUBAzremQD0rzD\\u002fkCwSdNAeRnIQCIh+kA="},"y":{"dtype":"f4","bdata":"LTHdPw03B0Cves0\u002f1fTbP+yBPD\u002f5qTm+e0jSP3oHsj\u002f\u002f+Cg\u002fc4sBQOIgvT8VtjA\u002fJ5+VPyDifT+ZaJ096dViP+alHUBmyCpAQ8eQPl+2uj8fzyM\u002f53SiP+a1\u002fD+YVkG+boIEv\u002fz9Mj7Ebx2\u002fda32PggNTT\u002fE5IA\u002fUelAvxoqxj8k1QNAVvPsPi23H0AKvhg\u002fhjMDPzNtxj\u002fPei5Asq4AQB9q6D+aGaY\u002fQzupP8erhr73jOM\u002fbJuaP2g5kj+f16Q\u002f5rq1P5490r7ff4Q\u002fVGOnP5PAZz++lIS9XDDSPxu+Ij\u002fx02S\u002fYLmev3vo+D9kF7S+ruadP9BT0z96VyE\u002fE2bUPojDmb7jjEo\u002fA9Ybv4rqG0ChlPQ\u002f5UOovspRYT8pkCNAVjIkQLvCIkDZxPM\u002fd6\u002fbvkxtJEDIWwdA\u002fWsiQOfqhj5+qdQ\u002fDXkIQGqNFD83Zw5A5eXvP+1xor+ZxxM\u002f2HtYP4va7j\u002fImTo\u002fgGbEPp0sOr++LEE\u002fmnGNPw5CkD9IFuq+REt9P6J5Eb1TAYk\u002f3hBIPggjlT\u002f4M+s\u002f9ZmBP7cTXr98\u002fkC\u002fnd6Dv5xL5j9JWlo\u002f8sPYP78\u002fQz9p6PY\u002f7NQaPeFnCEDLraA\u002fRreYvPPVqj\u002fgDrA\u002fhHS2P9OBzj5CXso\u002f\u002fsSLPw4pGj1RkMU\u002fWCr2Pw0AHL3hGvQ\u002fz7u6P\u002frz3D9PdGk+O0qWP69QLj8lUeM\u002fzpzrPuTSX78E868\u002fwbgFvx3EDEBp3ES+lsZlv48xNT8QVke+14wnPg8WyT+R8Ec\u002fd37VP7AJmz9bdhu\u002fDygyv1E1jj\u002fgl14\u002fydg\u002fP763WT+B75090BewP\u002fajLj4gRwFAly7WP9zH9T2ocNs+DWlUP+mWpj\u002fSrIQ9pAuzP3n0mz\u002fLe0E\u002fYDVUP3i3xz91f\u002fU\u002frIn1PyLgzj58Bw0\u002fGpWhP97QwT\u002fejcC+101+P151uD+azgc\u002fC9zFvq5F7D17Iqk\u002fQBGtvoqNgj8vLLm\u002fyVOEP8z1yD2mUKA\u002fcDQ0PkUVLUB8qxk\u002f0ywRPyHv4D8="},"z":{"dtype":"f4","bdata":"o0RKP3ue7D61MBRA3BMyQAG2BsCKax3ASruEvnypTcDNfpS\u002fkYyovQmeVT\u002fLy4HAORMFP2FAL8AlReu\u002fmmeyv44e1j\u002ftBnzAqtrEv97xTj7cqrg98bdowO3QlMDwXhjAe5QGwAZ8iMCrxju\u002fq\u002fL3v\u002fEARcCA+oLAqXA3v0NmRsC2Uoi\u002fBKa+v+SDOj+HZpG\u002fXlQ+vwz5e7+8BS5ATC4GQNH\u002fZcB8YPu\u002fRJxgwFaCET+Vy4Y\u002fBfmGwEU\u002fqr\u002fR32zALkLZP\u002fofAT9G3k5AVZKMwGzdgcAfqVRAqZveOWupBkB9ZNq\u002fpP5VwCUPRUDWxz3AUP8qQLZ2sj+80x9AKSGXvx\u002fQpD8p8UZAKMNqwEbfmz\u002fe7Yo\u002fDaixv0BS+D1AqqBA\u002fVJePx0w3D9mcGJAHmihPy805j+Sihc\u002fBVRBwOJk0r8ROIpAFTkWQAFZQEC9kso\u002fnjbgPzR1YcBSUldAtR6GQFPREEDfN01AXCdJQHc\u002fl78WzB1AfB\u002f6P1GpaEBu ...

# %% [markdown]
# ## Classification task

# %%
from sklearn.model_selection import train_test_split
SAMPLES_LIMIT=10000
X_train, X_test, y_train, y_test = train_test_split(X[:SAMPLES_LIMIT], y[:SAMPLES_LIMIT], test_size=0.2)

# %%
from sklearn import svm

clf = svm.SVC(C=1, gamma=0.001, random_state=0)
clf.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma=0.001)

# %%
from sklearn import metrics

y_pred = clf.predict(X_test)
print(f"Classification report for classifier {clf}:\n{metrics.classification_report(y_test, y_pred)}\n")
# Out:
# Classification report for classifier SVC(C=1, gamma=0.001):
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       178
#            1       0.89      0.97      0.93       215
#            2       0.90      0.89      0.90       196
#            3       0.90      0.85      0.87       190
#            4       0.90      0.92      0.91       206
#            5       0.88      0.91      0.89       206
#            6       0.94      0.98      0.96       202
#            7       0.93      0.90      0.91       222
#            8       0.96      0.85      0.90       188
#            9       0.88      0.89      0.88       197
#
#     accuracy                           0.91      2000
#    macro avg       0.92      0.91      0.91      2000
# weighted avg       0.92      0.91      0.91      2000

# %% [markdown]
# Calculate and display the confision matrix for `predicted` and `y_test` (use metrics package).

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix)
disp.plot();
